# %%
import sys, os
os.path.dirname(sys.executable)
# Out:
# '/clusterfs/nilah/sergio/miniconda3/envs/ESM_cambrian/bin'

# %%
sys.path.append('/global/scratch/users/sergiomar10/ESMCBA/ESMCBA/')
from ESMCBA.imports import *

# %%
evaluations_dt = pd.read_csv('../performances/models_performances_21032025.csv')
evaluations_dt = evaluations_dt.sort_values(by=['spearman','mse'], ascending = [False, True]).reset_index(drop=True)

# %%
# Copy the DataFrame
df_corr = evaluations_dt.copy()

# Convert 'encoding' to binary (e.g., epitope=0, HLA=1)
df_corr['Losses_binary'] = df_corr['Losses'].map({'MSE': 0, 'Hubber': 1})

# Convert 'encoding' to binary (e.g., epitope=0, HLA=1)
df_corr['encoding_binary'] = df_corr['encoding'].map({'epitope': 0, 'HLA': 1})

# Select numeric columns
numeric_hyperparams = df_corr[[
    'lr_transformer', 'lr_regression', 'trained_blocks', 'data_prop',  'spearman', 'pearsonr', 'mse'
]].astype(float)

# Compute correlation matrix
correlation_matrix = numeric_hyperparams.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Hyperparameter + Encoding Correlation with Metrics")
plt.show()


from scipy.stats import pointbiserialr
# Point-biserial correlation
r, p = pointbiserialr(df_corr['encoding_binary'], df_corr['spearman'])
print(f"Encoding vs Spearman correlation: {r:.3f} (p = {p:.3g})")

evaluations_dt['lr_transformer'] = evaluations_dt['lr_transformer'].astype(float)

sns.catplot(data=evaluations_dt, x='lr_transformer', y='spearman', hue='Losses', kind='box')
sns.catplot(data=evaluations_dt, x='lr_transformer', y='spearman', hue='encoding', kind='box')
# Out:
# Encoding vs Spearman correlation: nan (p = nan)

# %%
evaluations_dt_sorted = evaluations_dt[evaluations_dt['encoding'] == 'epitope'].sort_values(by='mse', ascending = True).drop_duplicates('HLA') #[evaluations_dt['Losses'] == 'MSE']
evaluations_dt_sorted = evaluations_dt_sorted[evaluations_dt_sorted['HLA'].apply(len) == 8] 
# evaluations_dt_sorted #.sort_values(by='spearman', ascending = False)

results = []
test_datasets_list = []

# Get unique HLA alleles
alleles = evaluations_dt_sorted['HLA'].unique()

for allele in alleles:
    # Load training data for the current allele
    formatted_HLA = allele.replace('*', '').replace(':', '')  # e.g., HLAB0801
    train_fasta = f"/global/scratch/users/sergiomar10/data/IEDB_SQL/IEDB_HLA{formatted_HLA}_final.csv"
    epitope_data = pd.read_csv(train_fasta, header=None)
    epitope_data.columns = ['sequence', 'ref_ID', 'submissionID', 'Epitope_ID', 'protein_origin', 
                            'ID_SOURCE', 'SOURCE_ORGANISM', 'IC50_nM', 'DESCRIPTION_BINDING', 'Year_submission']
    
    # Clean and filter the training data
    epitope_data['Year_submission'] = epitope_data['Year_submission'].astype(str).replace('\\N', '0').astype(int)
    epitope_data = epitope_data[epitope_data["Year_submission"] < 2019]

    # Load test data for the current allele
    test_path = evaluations_dt_sorted[evaluations_dt_sorted['HLA'] == allele]['path'].values[0]
    test_dataset = pd.read_csv(test_path)
    
    # Remove training sequences from the test data
    test_dataset = test_dataset[~test_dataset['sequence'].isin(epitope_data['sequence'])]
    
    # If the filtered test dataset is empty, skip this allele
    if test_dataset.empty:
        continue

    # Store the test dataset with an added column for HLA
    test_dataset = test_dataset.copy()  # Ensure we're not modifying the original DataFrame unexpectedly
    test_dataset['HLA'] = allele
    test_datasets_list.append(test_dataset)
    
    # Only compute metrics if there is more than one sample
    if len(test_dataset) > 1:
        spearman_val = spearmanr(test_dataset['measured'], test_dataset['prediction'])[0]
        pearson_val = pearsonr(test_dataset['measured'], test_dataset['prediction'])[0]
        mse_val = mean_squared_error(test_dataset['measured'], test_dataset['prediction'])
        
        # Format to 2 significant figures
        spearman_str = f"{spearman_val:.2g}"
        pearson_str = f"{pearson_val:.2g}"
        mse_str = f"{mse_val:.2g}"
        
        results.append({
            "HLA": allele,
            "spearman": spearman_str,
            "pearsonr": pearson_str,
            "mse": mse_str,
            "test_size": len(test_dataset),
            "path": test_path,
            "training_data": len(epitope_data),
        })

# Create a DataFrame with the metrics results
metrics_df = pd.DataFrame(results)

# Concatenate all test datasets into a single DataFrame
if test_datasets_list:
    test_datasets_df = pd.concat(test_datasets_list, ignore_index=True)
else:
    test_datasets_df = pd.DataFrame()  # empty DataFrame if no test datasets were stored

# Now you have:
# - metrics_df: contains the computed metrics for each HLA allele.
# - test_datasets_df: contains all the filtered test datasets with an HLA identifier.

# %%
pd.merge(left=metrics_df, right=evaluations_dt_sorted[['HLA','time']], on='HLA', how='left').sort_values(by='time').reset_index(drop=True)
# Out:
#          HLA spearman pearsonr      mse  test_size  \
# 0   HLAB1801     0.71     0.83     0.84         11
# 1   HLAA6801     0.79     0.82     0.59         39
# 2   HLAB3501        1        1     0.44          2
# 3   HLAA6802        1        1    0.065          2
# 4   HLAA0206        1        1   0.0002          2
# 5   HLAA0101     0.68     0.76      1.3        126
# 6   HLAB4402     0.52     0.53      1.2        116
# 7   HLAA0203        1        1  0.00042          2
# 8   HLAA0301      0.6     0.58      1.4        220
# 9   HLAB5101     0.82     0.89     0.29          7
# 10  HLAB5701     0.93     0.76     0.15          7
# 11  HLAA0201     0.59      0.6      1.7        472
# 12  HLAA1101      0.8      0.8     0.67        107
# 13  HLAB0702     0.64     0.73      1.1        108
# 14  HLAA3301     0.94        1    0.049          8
# 15  HLAA2601     0.73     0.82     0.67         15
# 16  HLAB1501     0.73     0.77     0.79         22
# 17  HLAA3001     0.57     0.62     0.57         10
# 18  HLAA2402     0.42      0.4      2.4        131
# 19  HLAB2705     0.59     0.73     0.91         60
# 20  HLAA3101     0.79     0.93     0.22          8
# 21  HLAB4001        1        1      1.1          2
# 22  HLAB3906     0.65     0.65     0.73         12
# 23  HLAB4403   -0.071     0.34      1.6          8
# 24  HLAC0701       -1       -1      1.5          2
# 25  HLAA3201        1        1      3.2          2
# 26  HLAB0801     0.35     0.46        1         52
# 27  HLAB3801     0.62     0.66      1.5         12
# 28  HLAB1402     0.71      0.6       17          6
# 29  HLAA0205        1        1    0.097          2
# 30  HLAB3901    0.042     0.24      1.7         12
#
#                                                  path  training_data  \
# 0   /global/scratch/users/sergiomar10/losses/ESMCB...           2148
# 1   /global/scratch/users/sergiomar10/losses/ESMCB...           3058
# 2   /global/scratch/users/sergiomar10/losses/ESMCB...           1652
# 3   /global/scratch/users/sergiomar10/losses/ESMCB...           6622
# 4   /global/scratch/users/sergiomar10/losses/ESMCB...           5906
# 5   /global/scratch/users/sergiomar10/losses/ESMCB...           3790
# 6   /global/scratch/users/sergiomar10/losses/ESMCB...           1683
# 7   /global/scratch/users/sergiomar10/losses/ESMCB...           6471
# 8   /global/scratch/users/sergiomar10/losses/ESMCB...           6278
# 9   /global/scratch/users/sergiomar10/losses/ESMCB...           2243
# 10  /global/scratch/users/sergiomar10/losses/ESMCB...           2274
# 11  /global/scratch/users/sergiomar10/losses/ESMCB...          16550
# 12  /global/scratch/users/sergiomar10/losses/ESMCB...           5717
# 13  /global/scratch/users/sergiomar10/losses/ESMCB...           3724
# 14  /global/scratch/users/sergiomar10/losses/ESMCB...           2937
# 15  /global/scratch/users/sergiomar10/losses/ESMCB...           3326
# 16  /global/scratch/users/sergiomar10/losses/ESMCB...           3788
# 17  /global/scratch/users/sergiomar10/losses/ESMCB...           1350
# 18  /global/scratch/users/sergiomar10/losses/ESMCB...           2477
# 19  /global/scratch/users/sergiomar10/losses/ESMCB...           2097
# 20  /global/scratch/users/sergiomar10/losses/ESMCB...           4876
# 21  /global/scratch/users/sergiomar10/losses/ESMCB...           2586
# 22  /global/scratch/users/sergiomar10/losses/ESMCB...             33
# 23  /global/scratch/users/sergiomar10/losses/ESMCB...            929
# 24  /global/scratch/users/sergiomar10/losses/ESMCB...             18
# 25  /global/scratch/users/sergiomar10/losses/ESMCB...            836
# 26  /global/scratch/users/sergiomar10/losses/ESMCB...           2374
# 27  /global/scratch/users/sergiomar10/losses/ESMCB...            149
# 28  /global/scratch/users/sergiomar10/losses/ESMCB...             80
# 29  /global/scratch/users/sergiomar10/losses/ESMCB...            110
# 30  /global/scratch/users/sergiomar10/losses/ESMCB...           1341
#
#                    time
# 0   2025-03-27 18:49:16
# 1   2025-03-27 23:02:52
# 2   2025-03-28 00:18:45
# 3   2025-03-28 00:56:47
# 4   2025-03-28 02:37:53
# 5   2025-03-28 03:38:57
# 6   2025-03-28 03:51:07
# 7   2025-03-28 06:25:01
# 8   2025-03-28 06:44:13
# 9   2025-03-28 06:54:08
# 10  2025-03-28 06:54:27
# 11  2025-03-28 07:28:59
# 12  2025-03-28 08:06:21
# 13  2025-03-28 08:49:31
# 14  2025-03-28 09:28:50
# 15  2025-03-28 09:52:16
# 16  2025-03-28 10:22:36
# 17  2025-03-28 11:17:44
# 18  2025-04-02 22:13:03
# 19  2025-04-03 00:19:44
# 20  2025-04-03 02:59:32
# 21  2025-04-03 04:12:37
# 22  2025-04-03 04:35:22
# 23  2025-04-04 10:16:39
# 24  2025-04-04 10:24:14
# 25  2025-04-04 10:32:56
# 26  2025-04-04 10:36:36
# 27  2025-04-04 11:40:46
# 28  2025-04-04 11:53:22
# 29  2025-04-04 12:01:06
# 30  2025-04-04 12:17:56

# %%
hla_sequences = []

# Process each HLA and its evaluation file
for hla, eval_path in evaluations_dt_sorted[evaluations_dt_sorted['encoding'] == 'epitope'][['HLA', 'path']].values:

    # # Load evaluation data
    dt = pd.read_csv(eval_path)
    sequences = dt['sequence'].unique()
    hla_formatted = f"HLA-{hla}"  # e.g., 'HLA-A1101'

    # Collect HLA and sequence pairs
    for seq in sequences:
        hla_sequences.append([hla_formatted, seq])

# %%
# Load Data S2: Monoallelic benchmark dataset with predictions
test_data = pd.read_csv('/global/scratch/users/sergiomar10/ESMCBA/Data_S2.csv')

# %%
test_data['hla'] = test_data['hla'].str.replace('-', '').str.replace('*', '').str.replace(':', '')  # Remove 'HLA-' prefix

# %%
evaluations_dt_sorted = evaluations_dt[evaluations_dt['encoding'] == 'epitope'].sort_values(by='mse', ascending = True) #.drop_duplicates('HLA') #[evaluations_dt['Losses'] == 'MSE']
evaluations_dt_sorted = evaluations_dt_sorted[evaluations_dt_sorted['HLA'].apply(len) == 8] 
# evaluations_dt_sorted #.sort_values(by='spearman', ascending = False)

# %%
IEDB_full = pd.read_csv('/global/scratch/users/sergiomar10/ESMCBA/ESMCBA/data/IEDB_full_subset_filtered_out_MHCFlurry.csv', sep = ',', header = 0)
IEDB_full.head()
# Out:
#   Assay - Qualitative Measurement         peptide MHC Restriction - Name
# 0                   Positive-High       LITGRLQSL                 HLA-A2
# 1                        Positive      LIYDSSLCDL                 HLA-A2
# 2                        Positive        GLLGTLVQ                 HLA-A2
# 3                        Positive       NLTISDVSV                 HLA-A2
# 4                        Positive  LPAVVGLSPGEQEY            HLA-B*35:01

# %%
IEDB_full['HLA'] = IEDB_full['MHC Restriction - Name'].str.replace('-', '').str.replace('*', '').str.replace(':', '')  # Remove 'HLA-' prefix

# %%
import re
# # Set up SLURM script directory
sh_file_dir = '/global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA'
os.makedirs(sh_file_dir, exist_ok=True)

evaluated_models_log = []  # Will hold dicts with info to save as CSV later


for hla in evaluations_dt_sorted['HLA'].unique():

    sorted_models = evaluations_dt_sorted[evaluations_dt_sorted['HLA'] == hla][['HLA', 'path']].values

    model_found = False

    for allele, eval_path in sorted_models:
        hla_clean = allele.replace('*', '').replace(':', '').replace(' ', '').replace('HLA', '').replace('-', '')
        model_dir = f'/global/scratch/users/sergiomar10/ESMCBA/models/weights'

        model_filename = os.path.basename(eval_path).replace('evaluation_', '').replace('.csv', '_final.pth')
        model_path = os.path.join(model_dir, model_filename)

        if not os.path.exists(model_path):
            print(f"❌ Model not found: {model_path}")
            continue  # try next one
        else:
            print(f"✅ Model found for {allele}: {model_path}")
            model_found = True
            break  # stop checking once you find a good model

    if not model_found:
        print(f"⚠️ Skipping HLA {hla} — no valid model found.")
        continue  # skip this HLA

    # Get peptides for this allele
    peptides = IEDB_full[IEDB_full['HLA'] == hla]['peptide'].unique()

        # Filter peptides
    peptides = [
        pep for pep in peptides
        if 8 <= len(pep) <= 11 and not re.search(r'[<\(\)\*\s\+]', pep)
    ]

    if len(peptides) == 0:
        print(f"⚠️ No peptides found for {allele}. Skipping.")
        continue

    # Prepare job script
    run_id = f"MS_QUALPEPTIDDES_MHCFLURRY_{hla_clean}"
    peptide_str = ' '.join(peptides)

    esmcba_cmd = (
        f"python3 /global/scratch/users/sergiomar10/ESMCBA/ESMCBA/ESMCBA/model_evaluation.py "
        f"--model_path {model_path} "
        f"--hla {allele} "
        f"--output_dir /global/scratch/users/sergiomar10/benchmark/MSE_loss/qualitative_predictions "
        f"--peptides {peptide_str}"
    )


    sh_filepath = os.path.join(sh_file_dir, f"{run_id}.sh")
    try:
        with open(sh_filepath, 'w') as sh_file:
            sh_file.write('#!/bin/bash\n')
            sh_file.write('#SBATCH --account=co_nilah\n')
            sh_file.write('#SBATCH --partition=savio3_gpu\n')
            sh_file.write('#SBATCH --qos=savio_lowprio\n')
            sh_file.write('#SBATCH --cpus-per-task=4\n')
            sh_file.write('#SBATCH --gres=gpu:1\n')
            sh_file.write('#SBATCH --time=00:40:00\n')
            sh_file.write(f'#SBATCH --job-name={run_id}\n')
            sh_file.write(f'#SBATCH --output=/global/scratch/users/sergiomar10/logs/MHCFlurry_evals/{run_id}_%j.out\n')
            sh_file.write(f'#SBATCH --error=/global/scratch/users/sergiomar10/logs/MHCFlurry_evals/{run_id}_%j.err\n')
            sh_file.write('\n')
            sh_file.write('source /clusterfs/nilah/sergio/miniconda3/etc/profile.d/conda.sh\n')
            sh_file.write('conda activate /clusterfs/nilah/sergio/miniconda3/envs/ESM_cambrian\n')
            sh_file.write('\n')
            sh_file.write(f"{esmcba_cmd}\n")

        os.chmod(sh_filepath, 0o755)
        print(f"✅ Created SLURM script: {sh_filepath}")

        evaluated_models_log.append({
    'HLA': allele,
    'model_path': model_path,
    'eval_path': eval_path,
    'script_path': sh_filepath,
    'num_peptides': len(peptides)
})

    except Exception as e:
        print(f"❌ Error creating script for {run_id}: {e}")
# Out:
# ✅ Model found for HLAA0206: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-06_AUG_1_HLAA0206_2_0.001_1e-06__1_A0206_Hubber_A0206_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_A0206.sh
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-05__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-05__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_0.0001_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__1_B4506_0404_Hubber_B4506_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4506_1_1e-05_1e-06__2_B4506_0404_Hubber_B4506_final.pth
# ⚠️ Skipping HLA HLAB4506 — no valid model found.
# ✅ Model found for HLAA0203: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_0.001_AUG_6_HLAA0203_2_0.001_0.001__2_A0203_Hubber_A0203_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_A0203.sh
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_0.0001_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-05__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__2_B1542_0404_Hubber_B1542_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB1542_2_1e-05_1e-06__1_B1542_0404_Hubber_B1542_final.pth
# ⚠️ Skipping HLA HLAB1542 — no valid model found.
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_1e-05_1e-05__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-05__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-05__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-06__1_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-06__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-05__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_1e-05_1e-05__2_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_1e-05_1e-05__1_B3701_0404_Hubber_B3701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-06__1_B3701_0404_Hubber_B3701_final.pth
# ✅ Model found for HLAB3701: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-05__1_B3701_0404_Hubber_B3701_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_B3701.sh
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_0.0001_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-05__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__2_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB2701_2_1e-05_1e-06__1_B2701_0404_Hubber_B2701_final.pth
# ⚠️ Skipping HLA HLAB2701 — no valid model found.
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_0.0001_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-05__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__2_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB2709_2_1e-05_1e-06__1_B2709_0404_Hubber_B2709_final.pth
# ⚠️ Skipping HLA HLAB2709 — no valid model found.
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_0.0001_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__2_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-06__1_B0802_0404_Hubber_B0802_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB0802_2_1e-05_1e-05__1_B0802_0404_Hubber_B0802_final.pth
# ⚠️ Skipping HLA HLAB0802 — no valid model found.
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-06__1_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_0.0001_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-06__2_B2702_0404_Hubber_B2702_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2702_1_1e-05_1e-05__2_B2702_0404_Hubber_B2702_final.pth
# ...
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_0.0001_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-06__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__1_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-06__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_1e-05_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-06__1_B3901_0404_Hubber_B3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_1_HLAB3901_1_0.0001_1e-05__2_HLAB3901_Hubber_HLAB3901_final.pth
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3901_1_1e-05_1e-05__2_B3901_0404_Hubber_B3901_final.pth
# ⚠️ Skipping HLA HLAB3901 — no valid model found.
# ✅ Model found for HLAB4402: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_3_HLAB4402_1_0.001_0.001__2_B4402_Hubber_B4402_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_B4402.sh
# ✅ Model found for HLAA0301: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_0.001_AUG_1_HLAA0301_1_0.001_1e-06__1_A0301_Hubber_A0301_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_A0301.sh
# ✅ Model found for HLAA0201: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_5_0.001_1e-06_AUG_6_HLAA0201_2_0.001_1e-06__2_A0201_Hubber_A0201_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_A0201.sh
# ❌ Model not found: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_1e-05_AUG_3_HLAA2402_1_0.0001_1e-06__2_HLAA2402_Hubber_HLAA2402_final.pth
# ✅ Model found for HLAA2402: /global/scratch/users/sergiomar10/ESMCBA/models/weights/ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_1_HLAA2402_1_0.0001_1e-06__2_A2402_0404_Hubber_A2402_final.pth
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/MS_QUALPEPTIDDES_MHCFLURRY_A2402.sh

# %%
model_path
# Out:
# '/global/scratch/users/sergiomar10/ESCMBA/models/weights/ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.0001_1e-06_AUG_3_HLAA2402_2_0.001_0.001__2_A2402_Hubber_A2402_final.pth'

# %%
eval_model_df = pd.DataFrame(evaluated_models_log)

# %%
eval_model_df['model_path'] = eval_model_df['model_path'].str.replace('/global/scratch/users/sergiomar10/models/','')

# %%
import shutil

destination_dir = '/global/scratch/users/sergiomar10/ESMCBA/ESMCBA'
os.makedirs(destination_dir, exist_ok=True)

for row in evaluated_models_log:
    src = row['model_path']
    filename = os.path.basename(src)
    dest = os.path.join(destination_dir, filename)

    try:
        shutil.copy2(src, dest)  # copy2 preserves metadata
        print(f"✅ Copied {filename} to {destination_dir}")
    except Exception as e:
        print(f"❌ Failed to copy {src} → {dest}: {e}")
# Out:
# ✅ Copied ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.0001_1e-06_AUG_1_HLAA0206_2_0.001_1e-06__1_A0206_Hubber_A0206_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_0.001_AUG_6_HLAA0203_2_0.001_0.001__2_A0203_Hubber_A0203_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB3701_1_0.0001_1e-05__1_B3701_0404_Hubber_B3701_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_1_HLAA2501_1_0.0001_1e-06__1_A2501_0404_Hubber_A2501_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_0.001_AUG_1_HLAA3301_5_0.001_1e-06__4_A3301_Hubber_A3301_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_6_HLAA6802_2_0.001_1e-06__4_A6802_Hubber_A6802_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_3_HLAB1402_2_1e-05_1e-06__1_B1402_0404_Hubber_B1402_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAC0401_2_0.0001_1e-06__1_C0401_0404_Hubber_C0401_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB4601_1_0.0001_1e-05__2_B4601_0404_Hubber_B4601_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_1_HLAB5701_2_0.0001_1e-05__1_B5701_Hubber_B5701_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAA0207_1_0.0001_1e-06__2_A0207_0404_Hubber_A0207_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_3_HLAA3101_2_0.0001_1e-06__2_A3101_0404_Hubber_A3101_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_5e-05_AUG_1_HLAC0802_2_0.0001_1e-05__2_C0802_0404_Hubber_C0802_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_20_ESMMASK_epitope_FT_15_0.0001_1e-05_AUG_6_HLAB5101_5_0.001_1e-06__3_B5101_Hubber_B5101_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.001_5e-05_AUG_1_HLAC0702_1_0.0001_1e-05__1_C0702_0404_Hubber_C0702_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_5e-05_AUG_3_HLAA0205_2_0.0001_1e-06__2_A0205_0404_Hubber_A0205_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAA0202_1_0.0001_1e-05__2_A0202_0404_Hubber_A0202_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB5801_2_0.0001_1e-06__2_B5801_0404_Hubber_B5801_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAC0501_2_0.0001_1e-06__2_C0501_0404_Hubber_C0501_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAB4501_2_0.0001_1e-05__2_B4501_0404_Hubber_B4501_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_15_0.001_5e-05_AUG_1_HLAA3201_2_0.0001_1e-06__1_A3201_0404_Hubber_A3201_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB3501_2_0.001_0.001__4_B3501_Hubber_B3501_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_3_HLAB1502_1_1e-05_1e-05__1_B1502_0404_Hubber_B1502_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAC1402_1_0.0001_1e-06__1_C1402_0404_Hubber_C1402_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAB3801_2_0.0001_1e-06__1_B3801_0404_Hubber_B3801_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_20_0.001_5e-05_AUG_1_HLAB5401_2_0.0001_1e-06__2_B5401_0404_Hubber_B5401_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_5e-05_AUG_3_HLAB1517_1_0.0001_1e-05__2_B1517_0404_Hubber_B1517_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAB4002_2_0.0001_1e-05__1_B4002_0404_Hubber_B4002_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_1_HLAC1203_1_0.0001_1e-05__2_C1203_0404_Hubber_C1203_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_3_HLAC1502_2_0.0001_1e-06__1_C1502_0404_Hubber_C1502_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.0001_1e-06_AUG_3_HLAA3001_4_0.0001_0.001__3_A3001_Hubber_A3001_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_1_HLAA6801_2_0.0001_1e-06__4_A6801_Hubber_A6801_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_15_0.001_5e-05_AUG_1_HLAC0602_2_0.0001_1e-06__1_C0602_0404_Hubber_C0602_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_15_0.001_1e-06_AUG_6_HLAB5301_1_0.0001_1e-05__1_B5301_0404_Hubber_B5301_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_3_HLAA1101_5_0.001_1e-06__2_A1101_Hubber_A1101_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_15_0.0001_1e-05_AUG_1_HLAA2601_5_0.001_0.001__4_A2601_Hubber_A2601_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB4001_1_0.0001_1e-06__2_B4001_0404_Hubber_B4001_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_1_HLAB0801_1_0.0001_1e-06__1_B0801_0404_Hubber_B0801_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_3_HLAC0303_1_0.0001_1e-05__2_C0303_0404_Hubber_C0303_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_0.001_AUG_3_HLAB1501_2_0.001_0.001__2_B1501_Hubber_B1501_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.001_5e-05_AUG_1_HLAC0701_2_0.0001_1e-05__1_C0701_0404_Hubber_C0701_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.0001_1e-05_AUG_6_HLAB1801_1_0.001_1e-06__4_B1801_Hubber_B1801_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_5e-05_AUG_6_HLAB1503_2_0.0001_1e-05__2_B1503_0404_Hubber_B1503_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB2705_2_0.0001_1e-06__2_B2705_0404_Hubber_B2705_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_6_HLAA0211_2_0.0001_1e-06__1_A0211_0404_Hubber_A0211_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_15_0.0001_0.001_AUG_6_HLAB0702_3_0.001_1e-06__4_B0702_Hubber_B0702_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-06_AUG_3_HLAB4403_1_0.0001_1e-06__1_B4403_0404_Hubber_B4403_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_20_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_6_HLAA0101_2_0.001_0.001__3_A0101_Hubber_A0101_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.95_30_ESMMASK_epitope_FT_25_0.001_1e-05_AUG_3_HLAB4402_1_0.001_0.001__2_B4402_Hubber_B4402_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_25_0.001_0.001_AUG_1_HLAA0301_1_0.001_1e-06__1_A0301_Hubber_A0301_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.8_30_ESMMASK_epitope_FT_5_0.001_1e-06_AUG_6_HLAA0201_2_0.001_1e-06__2_A0201_Hubber_A0201_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA
# ✅ Copied ESMCBA_epitope_0.5_30_ESMMASK_epitope_FT_20_0.001_1e-06_AUG_1_HLAA2402_1_0.0001_1e-06__2_A2402_0404_Hubber_A2402_final.pth to /global/scratch/users/sergiomar10/ESMCBA/ESMCBA

# %%
# Load Data S3: Training data for MHCflurry 2.0 BA predictor
training_data = pd.read_csv('/global/scratch/users/sergiomar10/ESMCBA/Data_S3.csv')
print(f"Training data shape: {training_data.shape}")
# Out:
# Training data shape: (713069, 12)

# %%
training_data['allele'] = training_data['allele'].str.replace('-', '').str.replace('*', '').str.replace(':', '')  # Remove 'HLA-' prefix

# %%
testing_set_filtered = pd.DataFrame()

for HLA in test_datasets_df['HLA'].unique():
    training_data_subset = training_data[training_data['allele'] == HLA]

    test_datasets_df_subset = test_datasets_df[test_datasets_df['HLA'] == HLA]
    test_datasets_df_subset = test_datasets_df_subset[~test_datasets_df_subset['sequence'].isin(training_data_subset['peptide'])]

    testing_set_filtered = pd.concat([testing_set_filtered, test_datasets_df_subset], ignore_index=True)

# %%
import os
import pandas as pd

# Load your test data
# testing_set_filtered = pd.read_csv("path/to/testing_set_filtered.csv")

# Output dirs
sh_file_dir = '/global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA'
output_dir = '/global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4'
mhcflurry_out_dir = '/global/scratch/users/sergiomar10/benchmark/MSE_loss/MHCFlurry'
os.makedirs(sh_file_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)
os.makedirs(mhcflurry_out_dir, exist_ok=True)

aa = set("ACDEFGHIKLMNPQRSTVWY")  # valid amino acids

# Loop through each HLA in testing set
unique_hlas = testing_set_filtered['HLA'].unique()
print(f"📊 Found {len(unique_hlas)} unique HLAs in testing set.")

for allele in unique_hlas:
    allele_peptides = testing_set_filtered[testing_set_filtered['HLA'] == allele]['sequence'].unique()
    allele_clean = allele.replace('HLA-', '').replace('*', '').replace(':', '').replace(' ', '')

    # Clean peptides
    cleaned_peptides = [
        ''.join([aa_ for aa_ in p if aa_.upper() in aa])
        for p in allele_peptides if isinstance(p, str)
    ]
    cleaned_peptides = [p for p in cleaned_peptides if p]

    if len(cleaned_peptides) == 0:
        print(f"⚠️ No valid peptides found for {allele}. Skipping.")
        continue

    run_id = f"EVAL_MHCFLURRY_TEST_{allele_clean}"

    # Save to .pep FASTA file
    pepe = allele_clean.replace('HLA', 'HLA-')
    fasta_filename = os.path.join(output_dir, f"{pepe}.pep")
    with open(fasta_filename, "w") as fout:
        for i, pep in enumerate(cleaned_peptides, 1):
            fout.write(f">pep{i}\n{pep}\n")

    print(f"📁 Saved {len(cleaned_peptides)} peptides for {allele} to {fasta_filename}")

    # Build mhcflurry and netMHCpan commands
    mhcflurry_outfile = os.path.join(mhcflurry_out_dir, f"{allele_clean}_mhc_flurry.csv")
    mhcflurry_cmd = (
        f"mhcflurry-predict --alleles {allele_clean} "
        f"--peptides {' '.join(cleaned_peptides)} "
        f"--out {mhcflurry_outfile}"
    )

    netmhc_cmd = (
        f"cd {output_dir} && "
        f"/global/scratch/users/sergiomar10/ESMCBA/tools/netMHCpan-4.1/netMHCpan "
        f"-a {allele_clean} -f {allele_clean}.pep -BA -xls -xlsfile {allele_clean}_netmhc.xls"
    )

    # Write SLURM script
    sh_filepath = os.path.join(sh_file_dir, f"{run_id}.sh")
    try:
        with open(sh_filepath, 'w') as sh_file:
            sh_file.write('#!/bin/bash\n')
            sh_file.write('#SBATCH --account=co_nilah\n')
            sh_file.write('#SBATCH --partition=savio2_1080ti\n')
            sh_file.write('#SBATCH --qos=savio_lowprio\n')
            sh_file.write('#SBATCH --cpus-per-task=4\n')
            sh_file.write('#SBATCH --gres=gpu:1\n')
            sh_file.write('#SBATCH --time=00:40:00\n')
            sh_file.write(f'#SBATCH --job-name={run_id}\n')
            sh_file.write(f'#SBATCH --output=/global/scratch/users/sergiomar10/logs/MHCFlurry_evals/{run_id}_%j.out\n')
            sh_file.write(f'#SBATCH --error=/global/scratch/users/sergiomar10/logs/MHCFlurry_evals/{run_id}_%j.err\n\n')
            sh_file.write('source /clusterfs/nilah/sergio/miniconda3/etc/profile.d/conda.sh\n')
            sh_file.write('conda activate /clusterfs/nilah/sergio/miniconda3/envs/cooltools\n\n')
            sh_file.write(f"{mhcflurry_cmd}\n")
            sh_file.write(f"{netmhc_cmd}\n")

        os.chmod(sh_filepath, 0o755)
        print(f"✅ Created SLURM script: {sh_filepath}")
    except Exception as e:
        print(f"❌ Error writing script for {allele}: {e}")
# Out:
# 📊 Found 29 unique HLAs in testing set.
# 📁 Saved 1 peptides for HLAA0206 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A0206.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA0206.sh
# 📁 Saved 1 peptides for HLAA0203 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A0203.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA0203.sh
# 📁 Saved 8 peptides for HLAA3301 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A3301.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA3301.sh
# 📁 Saved 2 peptides for HLAA6802 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A6802.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA6802.sh
# 📁 Saved 7 peptides for HLAB5701 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B5701.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB5701.sh
# 📁 Saved 8 peptides for HLAA3101 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A3101.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA3101.sh
# 📁 Saved 7 peptides for HLAB5101 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B5101.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB5101.sh
# 📁 Saved 2 peptides for HLAA3201 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A3201.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA3201.sh
# 📁 Saved 2 peptides for HLAB3501 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B3501.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB3501.sh
# 📁 Saved 11 peptides for HLAB3801 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B3801.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB3801.sh
# 📁 Saved 9 peptides for HLAA3001 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A3001.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA3001.sh
# 📁 Saved 39 peptides for HLAA6801 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A6801.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA6801.sh
# 📁 Saved 99 peptides for HLAA1101 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A1101.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA1101.sh
# 📁 Saved 15 peptides for HLAA2601 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A2601.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA2601.sh
# 📁 Saved 11 peptides for HLAB3906 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B3906.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB3906.sh
# 📁 Saved 2 peptides for HLAB4001 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B4001.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB4001.sh
# 📁 Saved 51 peptides for HLAB0801 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B0801.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB0801.sh
# 📁 Saved 21 peptides for HLAB1501 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B1501.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB1501.sh
# 📁 Saved 2 peptides for HLAC0701 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-C0701.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAC0701.sh
# 📁 Saved 11 peptides for HLAB1801 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B1801.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB1801.sh
# 📁 Saved 58 peptides for HLAB2705 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B2705.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB2705.sh
# 📁 Saved 107 peptides for HLAB0702 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B0702.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB0702.sh
# 📁 Saved 8 peptides for HLAB4403 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B4403.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB4403.sh
# 📁 Saved 125 peptides for HLAA0101 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A0101.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA0101.sh
# 📁 Saved 11 peptides for HLAB3901 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B3901.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB3901.sh
# 📁 Saved 116 peptides for HLAB4402 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-B4402.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAB4402.sh
# 📁 Saved 211 peptides for HLAA0301 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A0301.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA0301.sh
# 📁 Saved 466 peptides for HLAA0201 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A0201.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA0201.sh
# 📁 Saved 130 peptides for HLAA2402 to /global/scratch/users/sergiomar10/benchmark/MSE_loss/NETMHCSPAN4/HLA-A2402.pep
# ✅ Created SLURM script: /global/scratch/users/sergiomar10/slurm_jobs/MHCF_ESMCBA/EVAL_MHCFLURRY_TEST_HLAA2402.sh

# %%
allele_clean.replace('HLA', 'HLA-')
# Out:
# 'HLA-A2402'
